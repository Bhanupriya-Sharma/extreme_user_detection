# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv('/content/drive/My Drive/Final Data csv/Finals/Best_Ever_Dataset.csv')

# %%
df.rename(columns={'User_No': 'user_no'}, inplace=True)

# %%
df.head()

# %%
l=df[df['extreme_user']==0]
l2=df[df['extreme_user']==1]
y=[len(l),len(l2)]
x=[0,1]
at=sns.barplot(x,y)
plt.xlabel('Extreme users')
plt.ylabel('No. of users')
# Out:
# Text(0, 0.5, 'No. of users')

# %%
from plotly import graph_objects as go

# %%
data=pd.read_csv('/content/drive/My Drive/Final Data csv/Finals/Final_Sentiment_Analysis.csv')

# %%
p=(len(df[df['sentiment']=='positive'])/len(df))*100
n=(len(df[df['sentiment']=='negative'])/len(df))*100
nt=(len(df[df['sentiment']=='neutral'])/len(df))*100
fig = go.Figure(go.Funnelarea(text =['Positive','Neutral','Negative'],values =[p,nt,n] ,title = {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8364fde8-4d14-4252-ab6e-e6a93787de1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8364fde8-4d14-4252-ab6e-e6a93787de1a")) {
#                     Plotly.newPlot(
#                         '8364fde8-4d14-4252-ab6e-e6a93787de1a',
# ...

# %%
fig = go.Figure(go.Funnel(y = ['Positive','Neutral','Negative'], x = [p,nt,n],textposition = "inside",opacity = 0.65, marker = {"color": ["deepskyblue", "lightsalmon", "tan"],"line": {"width": [4, 2, 2, 3], "color": ["wheat", "wheat", "blue"]}},connector = {"line": {"color": "royalblue", "dash": "dot", "width": 3}}))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9b5883ac-e424-456e-b8f4-74f3516331e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9b5883ac-e424-456e-b8f4-74f3516331e8")) {
#                     Plotly.newPlot(
#                         '9b5883ac-e424-456e-b8f4-74f3516331e8',
# ...

# %%
grid = sns.FacetGrid(df, col='extreme_user', row='sentiment', size=2.2, aspect=1.6)
grid.map(plt.hist, 'retweet_count', alpha=.5, bins=5)
grid.add_legend();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.

# %%
grid = sns.FacetGrid(df, col='extreme_user', row='sentiment', size=2.2, aspect=1.6)
grid.map(plt.hist,'followers_count', alpha=.5, bins=5)
grid.add_legend();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.

# %%
axes = sns.factorplot('extreme_user','followers_count',data=df, aspect = 2.5, )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
axes = sns.factorplot('extreme_user','retweet_count',data=df, aspect = 2.5, )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
extreme_user='extreme_user'
non_extreme_user='non_extreme_user'
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
ax = sns.distplot(df[df['extreme_user']==1].sentiment_score, bins=20, label = extreme_user, ax = axes[0], kde =False)
ax.legend()
ax = sns.distplot(df[df['extreme_user']==0]., bins=20, label = non_extreme_user, ax = axes[1], kde =False)
ax.legend()

# %%
df[df['followers_count']>=1000000]
# Out:
#       user_no     user_id  ... sentiment  extreme_user
# 69         69    58243368  ...  positive             1
# 89         89    67378160  ...  positive             0
# 510       510   240649814  ...  positive             0
# 1784     1784  2613904818  ...  positive             1
#
# [4 rows x 10 columns]

# %%
#changing definition of extreme users and try to compare with results
ll=[]
for i in df.avg_time_difference_in_min:
  if (i<=165):
    ll.append(1)
  else :
    ll.append(0)

# %%
df['extreme_user']=ll

# %%
df.head()
# Out:
#    user_no   user_id  ... sentiment  extreme_user
# 0        0  13508182  ...  positive             0
# 1        1  14458945  ...  positive             1
# 2        2  16263847  ...  positive             0
# 3        3  16804541  ...  positive             0
# 4        4  16863403  ...   neutral             0
#
# [5 rows x 10 columns]

# %%
len(df[df['extreme_user']==1])
# Out:
# 5470

# %%
df.describe()
# Out:
#             user_no       user_id  ...  sentiment_score  extreme_user
# count  10984.000000  1.098400e+04  ...     1.098400e+04  10984.000000
# mean    5491.500000  8.814317e+17  ...    -1.679420e+15      0.423798
# std     3170.952013  5.059735e+17  ...     2.783052e+17      0.494182
# min        0.000000  1.350818e+07  ...    -9.223372e+18      0.000000
# 25%     2745.750000  7.492186e+17  ...     0.000000e+00      0.000000
# 50%     5491.500000  1.154803e+18  ...     0.000000e+00      0.000000
# 75%     8237.250000  1.262014e+18  ...     1.000000e+00      1.000000
# max    10983.000000  1.287341e+18  ...     9.223372e+18      1.000000
#
# [8 rows x 8 columns]

# %%
grid = sns.FacetGrid(df, col='extreme_user', row='sentiment', size=2.2, aspect=1.6)
grid.map(plt.hist,'sentiment_score', alpha=.5, bins=5)
grid.add_legend();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.

# %%
axes = sns.factorplot('extreme_user','sentiment_score',data=df, aspect = 2.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
axes = sns.factorplot('extreme_user','retweet_count',data=df, aspect = 2.5, )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
axes = sns.factorplot('extreme_user','followers_count',data=df, aspect = 2.5, )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
grid = sns.FacetGrid(df, col='extreme_user', row='sentiment', size=2.2, aspect=1.6)
grid.map(plt.hist,'avg_time_difference_in_min', alpha=.5, bins=5)
grid.add_legend();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.
